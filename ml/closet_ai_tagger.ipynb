# %%
from google.colab import drive
drive.mount('/content/drive')

import os

# !git clone https://YOUR_TOKEN@github.com/rdavid27/The-Closet.git /content/closet-ai

os.makedirs('/content/closet-ai/ml', exist_ok=True)
os.chdir('/content/closet-ai/ml')

print("Ready:", os.getcwd())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Cloning into '/content/closet-ai'...
# remote: Enumerating objects: 90, done.
# remote: Counting objects: 100% (90/90), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 90 (delta 25), reused 84 (delta 19), pack-reused 0 (from 0)
# Receiving objects: 100% (90/90), 570.31 KiB | 38.02 MiB/s, done.
# Resolving deltas: 100% (25/25), done.
# Ready: /content/closet-ai/ml

# %%
import torch
print(f"GPU available: {torch.cuda.is_available()}")
print(f"GPU name: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'None'}")

# !pip install timm datasets Pillow transformers -q

print("Dependencies installed")
# Out:
# GPU available: True
# GPU name: Tesla T4
# Dependencies installed

# %%
# !git config --global user.email "rakeshdaviddineshanjoseph@gmail.com"
# !git config --global user.name "rdavid27"
# !git add .
# !git commit -m "ml: update training notebook"
# !git push
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %%
from huggingface_hub import list_datasets

results = list(list_datasets(search="deepfashion", limit=10))
for r in results:
    print(r.id)
# Out:
# lirus18/deepfashion
# lirus18/deepfashion_with_captions
# ldhnam/deepfashion_controlnet
# ldhnam/deepfashion_controlnet_ezcaption
# Cournane/DeepFashionDenspose
# lirus18/deepfashion_with_captions_blowout
# lirus18/deepfashion_with_captions_blowout_stacked
# SaffalPoosh/deepFashion-with-masks
# HuangHaoyang/deepfashion_densepose
# ohicarip/deepfashion_bl

# %%
from datasets import load_dataset

print("Loading dataset...")
dataset = load_dataset("lirus18/deepfashion", split="train", trust_remote_code=True)

print(f"Dataset size: {len(dataset)}")
print(f"Features: {dataset.features}")
print(f"Sample item keys: {list(dataset[0].keys())}")
# Out:
# `trust_remote_code` is not supported anymore.
# Please check that the Hugging Face dataset 'lirus18/deepfashion' isn't based on a loading script and remove `trust_remote_code`.
# If the dataset is based on a loading script, please ask the dataset author to remove it and convert it to a standard format like Parquet.
# ERROR:datasets.load:`trust_remote_code` is not supported anymore.
# Please check that the Hugging Face dataset 'lirus18/deepfashion' isn't based on a loading script and remove `trust_remote_code`.
# If the dataset is based on a loading script, please ask the dataset author to remove it and convert it to a standard format like Parquet.
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading dataset...
# README.md:   0%|          | 0.00/476 [00:00<?, ?B/s]
# data/train-00000-of-00007-b658efbe2a0936(…):   0%|          | 0.00/490M [00:00<?, ?B/s]
# ...

# %%
for i in range(5):
    print(f"Sample {i}: {dataset[i]['caption']}")
    print()
# Out:
# Sample 0:
#
# Sample 1:
#
# Sample 2:
#
# Sample 3:
#
# Sample 4:

# %%
from huggingface_hub import list_datasets

results = list(list_datasets(search="fashion classification", limit=10))
for r in results:
    print(r.id)
# Out:
# adhamelarabawy/fashion_human_classification
# hectorferrandizsanchis/hm-fashion-classification-Hector-Ferrandiz-Sanchis

# %%
from huggingface_hub import list_datasets

results = list(list_datasets(search="clothing category", limit=10))
for r in results:
    print(r.id)

# %%
from huggingface_hub import list_datasets

results = list(list_datasets(search="fashion mnist", limit=10))
for r in results:
    print(r.id)
# Out:
# zalando-datasets/fashion_mnist
# mweiss/fashion_mnist_corrupted
# arize-ai/fashion_mnist_label_drift
# arize-ai/fashion_mnist_quality_drift
# mweiss/fashion_mnist_ambiguous
# aintech/vdf_PC_ANN_Fashion-MNIST_d784_euclidean
# dhruv-anand-aintech/vdf_PC_ANN_Fashion-MNIST_d784_euclidean_sample_10000
# dhruv-anand-aintech/vdf_PC_ANN_Fashion-MNIST_d784_euclidean_sample_1000
# dhruv-anand-aintech/vdf_PC_ANN_Fashion-MNIST_d784_euclidean_sample_2000
# EleutherAI/fake-fashion-mnist

# %%
from google.colab import userdata
import os

token = userdata.get('GITHUB_TOKEN')
# !git clone https://{token}@github.com/rdavid27/The-Closet.git /content/closet-ai

os.chdir('/content/closet-ai')
print("Ready:", os.getcwd())
# Out:
# Cloning into '/content/closet-ai'...
# remote: Enumerating objects: 90, done.
# remote: Counting objects: 100% (90/90), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 90 (delta 25), reused 84 (delta 19), pack-reused 0 (from 0)
# Receiving objects: 100% (90/90), 570.31 KiB | 2.85 MiB/s, done.
# Resolving deltas: 100% (25/25), done.
# Ready: /content/closet-ai

# %%
import os
os.chdir('/content/closet-ai')

# !git config --global user.email "rakeshdaviddineshanjoseph@gmail.com"
# !git config --global user.name "rdavid27"

# !git add ml/
# !git commit -m "ml: dataset exploration and environment setup"
# !git push
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date
